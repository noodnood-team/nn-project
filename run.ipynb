# %%
# !py DataPipeline/pipeline/s1_process_dataset.py
# Out:
# ClearML Task: created new task id=58cf32d318144c37b97416017f939b27
# ClearML results page: https://app.clear.ml/projects/b147aa3456ca4a51b6130e2dadebded0/experiments/58cf32d318144c37b97416017f939b27/output/log
# 2026-04-24 01:14:04,545 - clearml - INFO - Dataset.get() did not specify alias. Dataset information will not be automatically logged in ClearML Server.
# 2026-04-24 01:14:03.366481: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# INFO:__main__:Preprocessing step started
# INFO:DataPipeline.data.loader:start loading dataset from ClearML...
# ...

# %%
# !py DataPipeline/pipeline/s2_feature_engineering.py
# Out:
# ClearML Task: created new task id=016489f5b9da4b339dc23e0a7485e4c1
# ClearML results page: https://app.clear.ml/projects/b147aa3456ca4a51b6130e2dadebded0/experiments/016489f5b9da4b339dc23e0a7485e4c1/output/log
# 2026-04-24 01:14:45.842650: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-24 01:14:46.925750: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# INFO:__main__:Feature engineering step started
# INFO:__main__:Loaded processed dataframe, shape=(2893, 7)
# INFO:__main__:Feature engineering completed, shape=(2893, 11)
# ...

# %%
py DataPipeline/pipeline/s3_train_model.py
# Out:
# ClearML Task: overwriting (reusing) task id=92909516a97f414891879150c4669993
# ClearML results page: https://app.clear.ml/projects/b147aa3456ca4a51b6130e2dadebded0/experiments/92909516a97f414891879150c4669993/output/log
# 2026-04-24 01:15:24,433 - clearml.model - INFO - A model with uri "file://C:\Users\riwki\.cache\torch\hub\checkpoints\resnet18-f37072fd.pth" already exists. Selecting it
# 2026-04-24 01:15:24,434 - clearml.model - INFO - Selected model id: 40913d511d5e4b1897494a653d71ec53
# Epoch 1, Loss: 1.1177
# 2026-04-24 01:16:02,013 - clearml.storage - INFO - Starting upload: C:\Users\riwki\AppData\Local\Temp\.clearml.upload_model_wc3bplb3.tmp => https://files.clear.ml/NutritionAnalyser/step_train_base.92909516a97f414891879150c4669993/models/best_Resnet18_model.pth
# 2026-04-24 01:16:12,109 - clearml.storage - INFO - Uploading: 42.72MB from C:\Users\riwki\AppData\Local\Temp\.clearml.upload_model_wc3bplb3.tmp
# Epoch 2, Loss: 0.5449
# Epoch 3, Loss: 0.4951
# ...

# %%
# !py DataPipeline/pipeline/s4_evaluate_model.py
# Out:
# ClearML Task: overwriting (reusing) task id=23f4d74b7c3543409356dd84decdacaf
# ClearML results page: https://app.clear.ml/projects/b147aa3456ca4a51b6130e2dadebded0/experiments/23f4d74b7c3543409356dd84decdacaf/output/log
# 2026-04-24 01:34:25,443 - clearml.model - INFO - A model with uri "file://C:\Users\riwki\.cache\torch\hub\checkpoints\resnet18-f37072fd.pth" already exists. Selecting it
# 2026-04-24 01:34:25,444 - clearml.model - INFO - Selected model id: 40913d511d5e4b1897494a653d71ec53
# 2026-04-24 01:34:13.063684: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !py DataPipeline/pipeline/clearml_pipeline.py
# Out:
# Starting ClearML pipeline...
# ClearML Task: created new task id=6f565467a90941219f15d9fa2397f9ea
# ClearML results page: https://app.clear.ml/projects/69be7adc7bb444748f4a71276b19bfde/experiments/6f565467a90941219f15d9fa2397f9ea/output/log
# ClearML pipeline page: https://app.clear.ml/pipelines/69be7adc7bb444748f4a71276b19bfde/experiments/6f565467a90941219f15d9fa2397f9ea
# 2026-04-24 01:34:55,348 - clearml.util - WARNING - 3 task found when searching for `{'project_name': 'NutritionAnalyser', 'task_name': 'step_preprocess_base', 'include_archived': True, 'task_filter': {'status': ['created', 'queued', 'in_progress', 'published', 'stopped', 'completed', 'closed']}}`
# 2026-04-24 01:34:55,348 - clearml.util - WARNING - Selected task `step_preprocess_base` (id=58cf32d318144c37b97416017f939b27)
# ...
